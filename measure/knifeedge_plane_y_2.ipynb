# %%
# y-axis

import os, sys, numpy, time, datetime

start = time.time()

import NASCORX_System.base.Motor
import NASCORX_System.device.ML2437A
import NASCORX_System.base.libMotor as lib

class pycolor(object):
    RED = '\033[31m'
    ENDC = '\033[0m'
    
slider = NASCORX_System.base.Motor.slider()
pm = NASCORX_System.device.ML2437A.ml2437a(IP='192.168.100.161', GPIB=13)

t1 = time.time()
pm.measure()
t2 = time.time()
print(t2 - t1)

t = 1
while t > 0.7:
    t1 = time.time()
    pm.measure()
    t2 = time.time()
    t = t2 -t1
    print(t)
    

x = slider.query_position(pos=lib.MOTOR_XAXIS_POS)
y = slider.query_position(pos=lib.MOTOR_YAXIS_POS)
average = 10 # PowerMeter
length = 170
strk = 1
sleep_y = 0.5
now = datetime.datetime.now()
os.mkdir('/home/amigos/sakasai/jupyter/beam_mesure/data/data_at_{0:%Y%m%d-%H%M%S}'.format(now))
os.chdir('/home/amigos/sakasai/jupyter/beam_mesure/data/data_at_{0:%Y%m%d-%H%M%S}'.format(now))

data_y_cw = []
data_y_ccw = []


# y = 32 まで動かす
slider.slide_cw(strk=32, axis='Y')
a = input()
# 取り付ける

# ydirection_mesurement
## y_cw
for i in range(length+1):
    ret_1y = []
    ret_2y = []
    for i in range(average):
        ret_ = pm.measure() # system1
        ret_1y.append(ret_)
    ret_ave1 = round(numpy.mean(ret_1y), 6)
    ret_min = round(min(ret_1y), 6)
    ret_max = round(max(ret_1y), 6)
    data_y_cw.append([time.time(), round(y, 1), ret_ave1, ret_min, ret_max])
    numpy.savetxt('{0:%Y%m%d-%H%M%S}_y_cw.csv'.format(now), numpy.array(data_y_cw), delimiter=',', fmt=['%f', '%.0f', '%.6f', '%.6f', '%.6f'])
    slider.slide_cw(strk=strk, axis='Y')
    time.sleep(sleep_y)   
    msg = 'Axis : {0}\nStroke : {1} [mm]\nCoorValue : {0} = {2} [mm]\nDestinate : {0} = {3} '.format('Y', strk, y, length)
    print('============'+'Knifeedge Measurement'+'============')
    print(msg)
    print('=========================================\n\n')
    y = y + strk
y = length
slider.slide_ccw(strk=1, axis='Y') 

# 状態2に変更する
a = input()

for i in range(length+1):
    ret_1y = []
    ret_2y = []
    for i in range(average):
        ret_= pm.measure() # system1
        ret_1y.append(ret_)
    ret_ave1 = round(numpy.mean(ret_1y), 6)
    ret_min = round(min(ret_1y), 6)
    ret_max = round(max(ret_1y), 6)
    data_y_ccw.append([time.time(), round(y, 1), ret_ave1, ret_min, ret_max])
    numpy.savetxt('{0:%Y%m%d-%H%M%S}_y_ccw.csv'.format(now), numpy.array(data_y_ccw), delimiter=',', fmt=['%f', '%.0f', '%.6f', '%.6f', '%.6f'])
    slider.slide_ccw(strk=strk, axis='Y')
    time.sleep(sleep_y)   
    msg = 'Axis : {0}\nStroke : {1} [mm]\nCoorValue : {0} = {2} [mm]\nDestinate : {0} = {3} [mm]'.format('Y', strk, y, 'Origin!!')
    print('============'+'Knifeedge Measurement'+'============')
    print(msg)
    print('=========================================\n\n')
    y = y - strk
slider.return_org(out=lib.RETURN_ORIGIN_YAXIS) # return_origin
print(pycolor.RED + '\n\ny-axis Measurement finished!!!' + pycolor.ENDC)
print(pycolor.RED + 'y-axis Measurement finished!!!' + pycolor.ENDC)
print(pycolor.RED + 'y-axis Measurement finished!!!' + pycolor.ENDC)
print(pycolor.RED + '\n\n'
      '=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=\n'
      '   Finish : Knifeedge Measurement  \n'
      '=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=\n'
      'x-axis : 0 [mm] - {0} [mm] \n'
      'y-axis : 0 [mm] - {0} [mm] \n'.format(length) + pycolor.ENDC)

slider.close_board()
# Out:
# Interface GPG7400(1): open
# 1.5708708763122559
# 1.5752217769622803
# 1.573197603225708
# 1.5728373527526855
# 1.5719473361968994
# 1.573641061782837
# 0.6277852058410645
# Interface GPG7400(1): read_counter
# Interface GPG7400(1): read_counter
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = -0.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 1.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 2.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 3.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 4.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 5.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 6.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 7.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 8.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 9.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 10.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 11.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 12.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 13.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 14.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 15.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 16.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 17.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 18.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 19.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 20.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 21.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 22.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 23.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 24.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 25.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 26.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 27.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 28.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 29.0 [mm]
# Destinate : Y = 170
# =========================================
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 30.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 31.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 32.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 33.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 34.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 35.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 36.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 37.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 38.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 39.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 40.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 41.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 42.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 43.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 44.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 45.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 46.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 47.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 48.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 49.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 50.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 51.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 52.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 53.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 54.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 55.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 56.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 57.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 58.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 59.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 60.0 [mm]
# Destinate : Y = 170
# =========================================
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 61.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 62.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 63.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 64.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 65.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 66.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 67.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 68.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 69.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 70.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 71.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 72.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 73.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 74.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 75.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 76.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 77.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 78.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 79.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 80.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 81.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 82.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 83.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 84.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 85.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 86.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 87.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 88.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 89.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 90.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 91.0 [mm]
# Destinate : Y = 170
# =========================================
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 92.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 93.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 94.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 95.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 96.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 97.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 98.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 99.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 100.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 101.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 102.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 103.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 104.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 105.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 106.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 107.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 108.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 109.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 110.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 111.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 112.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 113.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 114.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 115.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 116.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 117.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 118.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 119.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 120.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 121.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 122.0 [mm]
# Destinate : Y = 170
# =========================================
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 123.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 124.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 125.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 126.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 127.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 128.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 129.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 130.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 131.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 132.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 133.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 134.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 135.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 136.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 137.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 138.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 139.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 140.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 141.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 142.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 143.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 144.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 145.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 146.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 147.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 148.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 149.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 150.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 151.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 152.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 153.0 [mm]
# Destinate : Y = 170
# =========================================
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 154.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 155.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 156.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 157.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 158.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 159.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 160.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 161.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 162.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 163.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 164.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 165.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 166.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 167.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 168.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 169.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 170.0 [mm]
# Destinate : Y = 170
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 170 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 169 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 168 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 167 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 166 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 165 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 164 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ...
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 55 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 54 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 53 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 52 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 51 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 50 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 49 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 48 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 47 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 46 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 45 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 44 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 43 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 42 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 41 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 40 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 39 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 38 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 37 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 36 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 35 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 34 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 33 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 32 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 31 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 30 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 29 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 28 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 27 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 26 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 25 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 24 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 23 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 22 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 21 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 20 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 19 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 18 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 17 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 16 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 15 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 14 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 13 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 12 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 11 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 10 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 9 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 8 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 7 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 6 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 5 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 4 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 3 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 2 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 1 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : Y
# Stroke : 1 [mm]
# CoorValue : Y = 0 [mm]
# Destinate : Y = Origin!! [mm]
# =========================================
#
#
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
#
#
# y-axis Measurement finished!!!
# y-axis Measurement finished!!!
# y-axis Measurement finished!!!
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#    Finish : Knifeedge Measurement
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# x-axis : 0 [mm] - 170 [mm]
# y-axis : 0 [mm] - 170 [mm]
#
# Interface GPG7400(1): close

# %%
slider.close_board()
# Out:
# Interface GPG7400(1): close

# %%
slider.slide_cw(strk=10, axis='Y')
# Out:
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion

# %%
slider.return_org(out=lib.RETURN_ORIGIN_YAXIS)
# Out:
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do

# %%
a = row_input()

# %%
import os, sys, numpy, time, datetime

start = time.time()

import NASCORX_System.base.Motor
import NASCORX_System.device.ML2437A
import NASCORX_System.base.libMotor as lib

class pycolor(object):
    RED = '\033[31m'
    ENDC = '\033[0m'
    
slider = NASCORX_System.base.Motor.slider()
# Out:
# Interface GPG7400(1): open
