# %%
# x-axis

import os, sys, numpy, time, datetime

start = time.time()

import NASCORX_System.base.Motor
import NASCORX_System.device.ML2437A
import NASCORX_System.base.libMotor as lib

class pycolor(object):
    RED = '\033[31m'
    ENDC = '\033[0m'
    
slider = NASCORX_System.base.Motor.slider()
pm = NASCORX_System.device.ML2437A.ml2437a(IP='192.168.100.161', GPIB=13)
x = slider.query_position(pos=lib.MOTOR_XAXIS_POS)
y = slider.query_position(pos=lib.MOTOR_YAXIS_POS)
average = 1 # PowerMeter
length = 195
strk = 1
sleep_x = 0.5
now = datetime.datetime.now()
os.mkdir('/home/amigos/sakasai/jupyter/beam_mesure/data/data_at_{0:%Y%m%d-%H%M%S}'.format(now))
os.chdir('/home/amigos/sakasai/jupyter/beam_mesure/data/data_at_{0:%Y%m%d-%H%M%S}'.format(now))

data_x_cw = []
data_x_ccw = []

# x = 32 まで動かす
# slider.slide_ccw(strk=32, axis='U')
#a = input()
# 取り付ける

# xdirection_mesurement
## x_ccw
for i in range(length+1):
    ret_1x = []
    ret_2x = []
    for i in range(average):
        ret_= pm.measure() # system1
        ret_1x.append(ret_)
        #ret_ = pm.measure() # system2
        #ret_2y.append(ret_)
        ret_2x.append(0)
    ret_ave1 = round(numpy.mean(ret_1x), 6)
    ret_ave2 = round(numpy.mean(ret_2x), 6)
    data_x_ccw.append([time.time(), round(x, 1), ret_ave1, ret_ave2])
    numpy.savetxt('{0:%Y%m%d-%H%M%S}_x_ccw.csv'.format(now), numpy.array(data_x_ccw), delimiter=',', fmt=['%f', '%.0f', '%.6f', '%.6f'])
    slider.slide_ccw(strk=strk, axis='U')
    time.sleep(sleep_x)   
    msg = 'Axis : {0}\nStroke : {1} [mm]\nCoorValue : {0} = {2} [mm]\nDestinate : {0} = {3} '.format('X', strk, x, length)
    print('============'+'Knifeedge Measurement'+'============')
    print(msg)
    print('=========================================\n\n')
    x = x + strk
x = length
slider.slide_cw(strk=1, axis='U') 

# 状態2に変更する
a = input()

for i in range(length+1):
    ret_1x = []
    ret_2x = []
    for i in range(average):
        ret_= pm.measure() # system1
        ret_1x.append(ret_)
        ret_2x.append(0)
    ret_ave1 = round(numpy.mean(ret_1x), 6)
    ret_ave2 = round(numpy.mean(ret_2x), 6)
    data_x_cw.append([time.time(), round(x, 1), ret_ave1, ret_ave2])
    numpy.savetxt('{0:%Y%m%d-%H%M%S}_x_cw.csv'.format(now), numpy.array(data_x_cw), delimiter=',', fmt=['%f', '%.0f', '%.6f', '%.6f'])
    slider.slide_cw(strk=strk, axis='U')
    time.sleep(sleep_x)   
    msg = 'Axis : {0}\nStroke : {1} [mm]\nCoorValue : {0} = {2} [mm]\nDestinate : {0} = {3} [mm]'.format('X', strk, x, 'Origin!!')
    print('============'+'Knifeedge Measurement'+'============')
    print(msg)
    print('=========================================\n\n')
    x = x - strk
slider.return_org(out=lib.RETURN_ORIGIN_XAXIS) # return_origin
print(pycolor.RED + '\n\nx-axis Measurement finished!!!' + pycolor.ENDC)
print(pycolor.RED + 'x-axis Measurement finished!!!' + pycolor.ENDC)
print(pycolor.RED + 'x-axis Measurement finished!!!' + pycolor.ENDC)
print(pycolor.RED + '\n\n'
      '=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=\n'
      '   Finish : Knifeedge Measurement  \n'
      '=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=\n'
      'x-axis : 0 [mm] - {0} [mm] \n'
      'y-axis : 0 [mm] - {0} [mm] \n'.format(length) + pycolor.ENDC)

slider.close_board()
# Out:
# Interface GPG7400(1): open
# Interface GPG7400(1): read_counter
# Interface GPG7400(1): read_counter
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 0.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 1.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 2.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 3.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 4.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 5.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 6.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 7.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 8.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 9.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 10.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 11.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 12.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 13.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 14.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 15.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 16.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 17.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 18.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 19.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 20.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 21.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 22.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 23.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 24.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 25.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 26.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 27.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 28.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 29.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 30.0 [mm]
# Destinate : X = 195
# =========================================
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 31.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 32.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 33.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 34.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 35.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 36.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 37.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 38.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 39.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 40.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 41.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 42.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 43.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 44.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 45.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 46.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 47.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 48.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 49.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 50.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 51.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 52.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 53.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 54.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 55.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 56.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 57.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 58.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 59.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 60.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 61.0 [mm]
# Destinate : X = 195
# =========================================
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 62.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 63.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 64.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 65.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 66.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 67.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 68.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 69.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 70.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 71.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 72.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 73.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 74.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 75.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 76.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 77.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 78.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 79.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 80.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 81.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 82.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 83.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 84.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 85.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 86.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 87.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 88.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 89.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 90.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 91.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 92.0 [mm]
# Destinate : X = 195
# =========================================
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 93.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 94.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 95.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 96.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 97.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 98.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 99.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 100.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 101.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 102.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 103.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 104.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 105.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 106.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 107.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 108.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 109.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 110.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 111.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 112.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 113.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 114.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 115.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 116.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 117.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 118.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 119.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 120.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 121.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 122.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 123.0 [mm]
# Destinate : X = 195
# =========================================
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 124.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 125.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 126.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 127.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 128.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 129.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 130.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 131.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 132.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 133.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 134.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 135.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 136.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 137.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 138.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 139.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 140.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 141.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 142.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 143.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 144.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 145.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 146.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 147.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 148.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 149.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 150.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 151.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 152.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 153.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 154.0 [mm]
# Destinate : X = 195
# =========================================
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 155.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 156.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 157.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 158.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 159.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 160.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 161.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 162.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 163.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 164.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 165.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 166.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 167.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 168.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 169.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 170.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion
# ============Knifeedge Measurement============
# Axis : X
# Stroke : 1 [mm]
# CoorValue : X = 171.0 [mm]
# Destinate : X = 195
# =========================================
#
#
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion

# %%
slider.close_board()
# Out:
# Interface GPG7400(1): close

# %%
slider.slide_cw(strk=10, axis='Y')
# Out:
# Interface GPG7400(1): set_pulse_out
# Interface GPG7400(1): set_motion
# Interface GPG7400(1): start_motion

# %%
pm.measure()
# Out:
# -2.08

# %%
slider.return_org(out=lib.RETURN_ORIGIN_XAXIS)
# Out:
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
# Interface GPG7400(1): output_do
